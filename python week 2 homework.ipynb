# %%
#basic 1
def Remove(duplicate): 
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list 
      
# test 
duplicate = [1,2,2,3,3,4] 
print(Remove(duplicate))

# %%
#basic 2
def find(ordered_list, element_to_find):
  start_index = 0
  end_index = len(ordered_list) - 1

  print(ordered_list, element_to_find) #to make testing easier
  
  while True:
    middle_index = int((end_index + start_index) / 2) #need to make sure this is an int and also + rather than -

    #changed the following section
    if middle_index == start_index or middle_index == end_index:
      if ordered_list[middle_index] == element_to_find or ordered_list[end_index] == element_to_find:
          return True
      else:
          return False
    
    middle_element = ordered_list[middle_index]
    if middle_element == element_to_find:
      return True
    elif middle_element > element_to_find:
      end_index = middle_index
    else:
      start_index = middle_index
  
if __name__=="__main__":
  l = [2, 4, 6, 8, 10]

  
  print(find(l, -1)) 
  print(find(l, 0)) 
  print(find(l, 2)) 
  print(find(l, 3)) 
  print(find(l, 4)) 
  print(find(l, 5)) 
  print(find(l, 6)) 
  print(find(l, 7))
  print(find(l, 8))
  print(find(l, 9)) 
  print(find(l, 10)) 
  print(find(l, 11))
  print(find(l, 6.5))

# %%
#basic 3
a = [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]
b = [i for i in a if i % 2 == 0]
print(b)

# %%
#advanced1
def numberguess():
    import random
    x=random.randint(1,201)
    attempts=0
    while True:
        y=int(input("please enter a number from 1 to 200: "))
        attempts+=1
        if y>x+50:
            print("way upper")
        elif y>x:
            print("upper")
        elif y<x-50:
            print("way lower")
        elif y<x:
            print("lower")    
        elif y==x:
            print(f"bingo! you've tried {attempts}\ times")
            return
numberguess()

# %%
#advanced2
def test():
    varmin = 1
    varmax = 200
    found = False
    while not found:
        guess = round((varmax+varmin)/2)
        ans = input("Is your input way larger (wl), larger (l), way smaller (ws), smaller(s), or equal to (e) than " + str(guess) + " ")
        if ans == "wl":
            varmin = guess + 49
        elif ans == "l":
            varmin = guess
        elif ans == "ws":
            varmax = guess - 49
        elif ans == "s":
            varmax = guess
        elif ans == "e":
            print("Yay! I got it!")
            found = True
test()

# %%
#advanced3
def test():
    import random
    x = random.randint(1,201)
    attempts = 0
    while True:
        y = int(input("please enter a number from 1 to 200: "))
        attempts += 1
        if y > x + 50:
            print("way upper")
        elif y > x and attempts == 3:
            if x % 2 == 0:
                print("upper and even")
            elif x % 2 == 1:
                print("upper and odd")
                
        elif y < x and attempts == 3:
            if x % 2 == 0:
                print("lower and even")
            elif x % 2 == 1:
                print("lower and odd")
            
        elif y > x:
            print("upper")
        elif y < x - 50:
            print("way lower")
        elif y < x:
            print("lower")
        elif y == x:
            print(f"bingo! you've tried %d times" %attempts)
            return

test()

# %%
#advanced4
def test():
    found = False
    count = 0
    varmin = 1
    varmax = 200

    ans0 = input("Is your number even(e) or odd(o)")
    if ans0 == "e":
        situ = 0
    elif ans0 == "o":
        situ = 1
        
    while not found:
        if situ == 0:
            guess = round((varmax+varmin)/4)*2
        elif situ == 1:
            guess = round((varmax+varmin)/4)*2 + 1
        
        ans = input("Is your input way larger (wl), larger (l), way smaller (sw), smaller(s), or equal to (e) than " + str(guess) + " ")
        if ans == "wl":
            varmin = guess + 49
            count = count + 1
        elif ans == "l":
            varmin = guess
            count = count + 1
        elif ans == "ws":
            varmax = guess - 49
            count = count + 1
        elif ans == "s":
            varmax = guess
            count = count + 1
        elif ans == "e":
            count = count + 1
            print("Yay! I got it in %d tries!" %count)
            found = True

test()
